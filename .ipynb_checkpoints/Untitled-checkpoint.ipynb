# %%
import requests
from bs4 import BeautifulSoup

# %%
class ElComercioScrapper():
    diary = "El Comercio"
    base_url_elComercio = "https://elcomercio.pe"
    url_coronavirus_news = "https://elcomercio.pe/noticias/coronavirus-peru/"
    soup = []
    articles = []
    articles_soup = []
    
    def __init__(self, limit = 5):
        self.limit = limit
    
    def fetch_news(self):
        page = requests.get(self.url_coronavirus_news)
        self.soup = BeautifulSoup(page.content, 'html.parser')
    
    def fetch_articles(self):
        articles_soup = self.soup.findAll("div", {"class": "story-item"})
        self.articles_soup = articles_soup[:self.limit]
        
    def get_data_from_articles(self, story):
        time = story.find("p", {"class": "story-item__date"})
        title = story.find("a", {"class": "story-item__title"})
        img_src = story.find("img")
        subtitle = story.find("p", {"class": "story-item__subtitle"})
        
        return {
            "time": time.get_text(),
            "title": title.get_text(),
            "img_src": img_src.get('data-src'),
            "subtitle": subtitle.get_text(),
            "article_url": self.base_url_elComercio + title.get('href')
        }
    
    def build_json_articles(self):
        json_list = []
        for article in self.articles_soup:
            article_json = self.get_data_from_articles(article)
            json_list.append(article_json)
        
        self.articles = json_list
    
    def get_articles(self):
        self.fetch_news()
        self.fetch_articles()
        self.build_json_articles()
        
        return {
            "diary": self.diary,
            "articles": self.articles
        }

# %%
class RPPScrapper():
    diary = "RPP"
    base_url_rpp = "https://rpp.pe"
    url_coronavirus_news = "https://rpp.pe/noticias/coronavirus?ref=rpp"
    soup = []
    articles = []
    articles_soup = []
    
    def __init__(self, limit = 5):
        self.limit = limit
    
    def fetch_news(self):
        page = requests.get(self.url_coronavirus_news)
        self.soup = BeautifulSoup(page.content, 'html.parser')
    
    def fetch_articles(self):
        articles_soup = self.soup.findAll("article")
        self.articles_soup = articles_soup[:self.limit]
        
    def get_data_from_articles(self, story):
        time = story.find("time", {"class": "x-ago"})
        title = story.find("h2").find("a")
        img_src = story.find("figure")
        subtitle = story.find("p")
        #print(img_src)
        return {
            "time": time.get("data-x"),
            "title": title.get_text(),
            "img_src": self.get_internal_image(title.get('href')),
            "subtitle": subtitle.get_text(),
            "article_url": title.get('href')
        }
    
    def get_internal_image(self, article_url):
        article = requests.get(article_url)
        article_soup = BeautifulSoup(article.content, 'html.parser')
        picture = article_soup.find("div", {"class": "cover"})
        img = picture.find("img")
        return img.get('src')
    
    def build_json_articles(self):
        json_list = []
        for article in self.articles_soup:
            article_json = self.get_data_from_articles(article)
            json_list.append(article_json)
        
        self.articles = json_list
    
    def get_articles(self):
        self.fetch_news()
        self.fetch_articles()
        self.build_json_articles()
        
        return {
            "diary": self.diary,
            "articles": self.articles
        }

# %%
class LaRepublicaScrapper():
    diary = "La República"
    base_url_laRepublica = "https://larepublica.pe"
    url_coronavirus_news = "https://larepublica.pe/tag/coronavirus-en-peru/"
    soup = []
    articles = []
    articles_soup = []
    
    def __init__(self, limit = 5):
        self.limit = limit
    
    def fetch_news(self):
        page = requests.get(self.url_coronavirus_news)
        self.soup = BeautifulSoup(page.content, 'html.parser')
    
    def fetch_articles(self):
        articles_soup = self.soup.findAll("article", {"class": "PostSection"})
        self.articles_soup = articles_soup[:self.limit]
        
    def get_data_from_articles(self, story):
        time = story.find("span", {"class": "PostSectionListSPAN"})
        title = story.find("a", {"class": "PostSectionListA"})
        img_src = story.find("img")
        subtitle = story.find("p", {"class": "PostSectionContent"})
        
        article_url = self.base_url_laRepublica + title.get('href')
        
        return {
            "time": time.get_text(),
            "title": title.get_text(),
            "img_src": self.get_internal_image(article_url),
            "subtitle": subtitle.get_text(),
            "article_url": article_url
        }
    
    def get_internal_image(self, article_url):
        article = requests.get(article_url)
        article_soup = BeautifulSoup(article.content, 'html.parser')
        try:
            picture = article_soup.find("picture")
            img = picture.find("source", {"media": "(max-width: 767px)"})
            return img.get('srcset')
        except:
            return ""
    
    def build_json_articles(self):
        json_list = []
        for article in self.articles_soup:
            article_json = self.get_data_from_articles(article)
            json_list.append(article_json)
        
        self.articles = json_list
    
    def get_articles(self):
        self.fetch_news()
        self.fetch_articles()
        self.build_json_articles()
        
        return {
            "diary": self.diary,
            "articles": self.articles
        }

# %%
class Peru21Scrapper():
    diary = "Perú21"
    base_url_peru21 = "https://peru21.pe"
    url_coronavirus_news = "https://peru21.pe/noticias/coronavirus/"
    soup = []
    articles = []
    articles_soup = []
    
    def __init__(self, limit = 5):
        self.limit = limit
    
    def fetch_news(self):
        page = requests.get(self.url_coronavirus_news)
        self.soup = BeautifulSoup(page.content, 'html.parser')
    
    def fetch_articles(self):
        articles_soup = self.soup.findAll("div", {"class": "story-item"})
        self.articles_soup = articles_soup[:self.limit]
        
    def get_data_from_articles(self, story):
        time = story.find("p", {"class": "story-item__date"})
        title = story.find("a", {"class": "story-item__title"})
        img_src = story.find("img")
        subtitle = story.find("p", {"class": "story-item__subtitle"})
        
        return {
            "time": time.get_text(),
            "title": title.get_text(),
            "img_src": img_src.get('data-src'),
            "subtitle": subtitle.get_text(),
            "article_url": self.base_url_peru21 + title.get('href')
        }
    
    def build_json_articles(self):
        json_list = []
        for article in self.articles_soup:
            article_json = self.get_data_from_articles(article)
            json_list.append(article_json)
        
        self.articles = json_list
    
    def get_articles(self):
        self.fetch_news()
        self.fetch_articles()
        self.build_json_articles()
        
        return {
            "diary": self.diary,
            "articles": self.articles
        }

# %%
class CorreoScrapper():
    diary = "Correo"
    base_url_correo = "https://diariocorreo.pe"
    url_coronavirus_news = "https://diariocorreo.pe/noticias/coronavirus/"
    soup = []
    articles = []
    articles_soup = []
    
    def __init__(self, limit = 5):
        self.limit = limit
    
    def fetch_news(self):
        page = requests.get(self.url_coronavirus_news)
        self.soup = BeautifulSoup(page.content, 'html.parser')
    
    def fetch_articles(self):
        articles_soup = self.soup.findAll("div", {"class": "story-item"})
        self.articles_soup = articles_soup[:self.limit]
        
    def get_data_from_articles(self, story):
        title = story.find("a", {"class": "story-item__title"})
        subtitle = story.find("p", {"class": "story-item__subtitle"})
        article_url = self.base_url_correo + title.get('href')
        img_src, time = self.get_internal_data(article_url)
        
        return {
            "time": time,
            "title": title.get_text(),
            "img_src": img_src,
            "subtitle": subtitle.get_text(),
            "article_url": self.base_url_correo + title.get('href')
        }
    
    def get_internal_data(self, article_url):
        article = requests.get(article_url)
        article_soup = BeautifulSoup(article.content, 'html.parser')
        try:
            picture = article_soup.find("picture")
            img = picture.find("source", {"media": "(max-width: 767px)"}).get('srcset')
        except:
            img = ""
        time = article_soup.find("time").get("datetime")

        return img, time
    
    def build_json_articles(self):
        json_list = []
        for article in self.articles_soup:
            article_json = self.get_data_from_articles(article)
            json_list.append(article_json)
        
        self.articles = json_list
    
    def get_articles(self):
        self.fetch_news()
        self.fetch_articles()
        self.build_json_articles()
        
        return {
            "diary": self.diary,
            "articles": self.articles
        }

# %%
class Extractor():
    
    articles = []
    
    def select_daily(self, diary):
        newspapers = {
            "el_comercio": 'el_comercio',
            "la_republica": 'la_republica',
            "rpp": 'rpp',
            "peru21": "peru21",
            "correo": "correo"
        }
        
        if diary == "all":
            return newspapers
        
        return newspapers.get(diary, "Diario seleccionado invalido")
    
    
    def scrape_articles(self, selected_daily, limit):
        if selected_daily == "el_comercio":
            elComercio_scrapper = ElComercioScrapper(limit)
            elComercio_data = elComercio_scrapper.get_articles()
            self.articles.append(elComercio_data)
        if selected_daily == "la_republica":
            laRepublica_scrapper = LaRepublicaScrapper(limit)
            laRepublica_data = laRepublica_scrapper.get_articles()
            self.articles.append(laRepublica_data)
        if selected_daily == "rpp":
            rpp_scrapper = RPPScrapper(limit)
            rpp_data = rpp_scrapper.get_articles()
            self.articles.append(rpp_data)
        if selected_daily == "peru21":
            peru21_scrapper = Peru21Scrapper(limit)
            peru21_data = peru21_scrapper.get_articles()
            self.articles.append(peru21_data)
        if selected_daily == "correo":
            correo_scrapper = CorreoScrapper(limit)
            correo_data = correo_scrapper.get_articles()
            self.articles.append(correo_data)


    def get_articles(self, selected_daily, limit):
        print(selected_daily, limit)
        self.scrape_articles(selected_daily, limit)
        return self.articles

# %%
class NewScrapper(Extractor):
    
    def __init__(self, diary, limit= 5):
        self.diary = diary
        self.limit = limit
        self.selected_daily = self.select_daily(diary)

    def get_news(self):
        articles = self.get_articles(self.selected_daily, self.limit)
        return articles

# %%
x = NewScrapper("rpp")
x.get_news()
# Out:
# rpp 5
# [{'diary': 'La República',
#   'articles': [{'time': '29 Mar 2020 | 3:51 h',
#     'title': 'Coronavirus en Perú: Infarto económico y recuperación',
#     'img_src': 'https://larepublica.pe/resizer/xO-UB8vkOl7vVEFFDTtszXgWm9Q=/482x290/top/smart/arc-anglerfish-arc2-prod-gruporepublica.s3.amazonaws.com/public/DWJ3LXLOVVCWTFISD6U3TVZIW4.png',
#     'subtitle': 'Para atacar la crisis económica desatada por el Covid-19 es necesario distinguir entre dos etapas. La primera estará dominada por la paralización económica interna y el congelamiento masivo de flujos de ingresos en hogares y empresas, y requerirá políticas excepcionales de alivio. La segunda estará marcada por un menor gasto agregado y la persistencia del shock externo, y demandará de medidas más tradicionales de estímulo. Ambas exigirán actuar decididamente para evitar quiebras y la ruptura de la cadena de pagos.',
#     'article_url': 'https://larepublica.pe/economia/2020/03/29/coronavirus-en-peru-infarto-economico-y-recuperacion/'},
#    {'time': '29 Mar 2020 | 2:52 h',
#     'title': 'Van 16 muertos en dos semanas de aislamiento',
#     'img_src': 'https://larepublica.pe/resizer/Bg2vsMvCg5FoxLdPWhTjqGOyHLQ=/482x290/top/smart/arc-anglerfish-arc2-prod-gruporepublica.s3.amazonaws.com/public/UEJSSZWMTFAMHC6GVE4VFCMLLQ.jpg',
#     'subtitle': 'Curva ascendente. Casos positivos de COVID-19 llegaron ayer a 671 en todo el país y en 48 horas se reportan cinco nuevas víctimas mortales. Uno de los fallecidos es un turista chino que llegó al país el 12 de marzo y luego visitó Machu Picchu.',
#     'article_url': 'https://larepublica.pe/sociedad/2020/03/29/coronavirus-peru-van-16-muertos-en-dos-semanas-de-aislamiento/'},
#    {'time': '29 Mar 2020 | 2:37 h',
#     'title': 'Coronavirus en Perú: cifra de infectados sube a 671, afirmó Martín Vizcarra [VIDEO]',
#     'img_src': 'https://larepublica.pe/resizer/5MsLOIUavbnFt77cSvSNGE-ehJo=/482x290/top/smart/arc-anglerfish-arc2-prod-gruporepublica.s3.amazonaws.com/public/GS3BSNMYBBBDRJYP35N75IF424.jpg',
#     'subtitle': 'De acuerdo al último reporte, se han procesado 10 896 muestras en todo el país a cargo del Instituto Nacional del Perú y laboratorios asociados al Ministerio de Salud. ',
#     'article_url': 'https://larepublica.pe/sociedad/2020/03/28/coronavirus-peru-aumenta-a-671-los-pacientes-con-covid-19-en-peru-afirmo-martin-vizcarra-video/'},
#    {'time': '29 Mar 2020 | 1:48 h',
#     'title': 'Detienen a regidor de Trujillo por incumplir toque de queda',
#     'img_src': 'https://larepublica.pe/resizer/5MoUEqDqJnYaMabqU-OqD72SBh0=/482x290/top/smart/arc-anglerfish-arc2-prod-gruporepublica.s3.amazonaws.com/public/HCEYFTSJRZD2VK4X2P3PEQWD3E.gif',
#     'subtitle': 'Arístides Saldaña fue intervenido en las calles de El Porvenir. Autoridad afirmó tener un permiso especial.',
#     'article_url': 'https://larepublica.pe/sociedad/2020/03/29/detienen-a-regidor-de-trujillo-por-incumplir-toque-de-queda-coronavirus-covid-19-toque-de-queda-lrnd/'},
#    {'time': '29 Mar 2020 | 1:22 h',
#     'title': 'Ministro de Salud supervisó avances en Villa Panamericana [FOTOS]',
#     'img_src': '',
#     'subtitle': 'Victor Zamora, titular del Minsa, acudió a las instalaciones de la Villa Panamericana e inspeccionó su acondicionamiento para recibir a pacientes de coronavirus.',
#     'article_url': 'https://larepublica.pe/sociedad/2020/03/29/coronavirus-en-peru-ministro-de-salud-superviso-avances-en-villa-panamericana-fotos-mdga/'}]},
#  {'diary': 'El Comercio',
#   'articles': [{'time': '2020-03-28',
#     'title': 'CTS por coronavirus: ¿cómo realizar el retiro de hasta S/2.400 autorizado por el Gobierno?',
#     'img_src': 'https://elcomercio.pe/resizer/4HtLUbU8QMFz-EG3r2L9ae7mT3A=/234x161/smart/arc-anglerfish-arc2-prod-elcomercio.s3.amazonaws.com/public/YGD7M3C5WJB5LMLX5EUPVZEIQE.jpg',
#     'subtitle': 'El Poder Ejecutivo emitió un Decreto de Urgencia en el cual explica cómo los trabajadores podrán acceder a los fondos de su CTS ante la cuarenten...',
#     'article_url': 'https://elcomercio.pe/economia/peru/cts-por-coronavirus-peru-como-se-podra-hacer-el-retiro-de-hasta-s2400-autorizado-por-el-gobierno-covid-19-bancos-nndc-noticia/'},
#    {'time': '2020-03-28',
#     'title': 'Coronavirus: ¿cómo retirar tu CTS durante la cuarentena? ',
#     'img_src': 'https://elcomercio.pe/resizer/KxBaBHREHsYds0YBSgiFqf1TekQ=/234x161/smart/arc-anglerfish-arc2-prod-elcomercio.s3.amazonaws.com/public/3UTP7XG4LZHYXIEMZQCXXMWM7Y.jpg',
#     'subtitle': 'Recuerde que en caso de desempleo podrá disponer del total de la CTS que ha venido acumulando durante el periodo en el que se encontraba laborand...',
#     'article_url': 'https://elcomercio.pe/economia/coronavirus-peru-cts-sepa-como-retirar-hasta-s2400-sin-problemas-nndc-noticia/'},
#    {'time': '2020-03-28',
#     'title': 'Coronavirus MAPA EN VIVO: mira la evolución de la pandemia en tiempo real, hoy sábado 28 de marzo',
#     'img_src': 'https://elcomercio.pe/resizer/qlOA7rKzdz54TNQ9PWTH0TOer84=/234x161/smart/arc-anglerfish-arc2-prod-elcomercio.s3.amazonaws.com/public/4QCLKWSEL5GKRLQ5PRE5QQ7PYY.jpg',
#     'subtitle': 'Sigue en vivo y en directo el mapa del coronavirus en el mundo con la evolución de las cifras en cada país: casos, infectados, recuperados y muer...',
#     'article_url': 'https://elcomercio.pe/tecnologia/ciencias/pandemia-coronavirus-mapa-en-vivo-sigue-en-tiempo-real-el-avance-del-covid-19-casos-en-tiempo-real-casos-en-peru-coronavirus-en-latinoamerica-paises-mas-afectados-wuhan-china-estados-unidos-francia-italia-espana-noticia/'},
#    {'time': '2020-03-28',
#     'title': 'CTS: ¿sabes en qué bancos hacer el retiro? conoce aquí dónde y cuándo ',
#     'img_src': 'https://elcomercio.pe/resizer/FeB9DFFfPNJee5WfjKTj5L5mjlE=/234x161/smart/arc-anglerfish-arc2-prod-elcomercio.s3.amazonaws.com/public/UXE3Q7Q3KZDKVPGPVTO3FWBIYY.jpg',
#     'subtitle': 'La respuesta de diversas entidades financieras a lo decretado en el mensaje a la nación del jueves 26 de marzo no demoró y se puede retirar dicho...',
#     'article_url': 'https://elcomercio.pe/economia/peru/coronavirus-peru-cts-en-que-bancos-ya-se-puede-hacer-el-retiro-de-hasta-2400-soles-martin-vizcarra-compensacion-por-tiempo-de-servicios-bcp-scotiabank-interbank-bbva-covid-19-noticia/'},
#    {'time': '2020-03-28',
#     'title': 'Bono 380 soles: ¿eres beneficiario del subsidio? sigue los pasos para realizar el retiro ',
#     'img_src': 'https://elcomercio.pe/resizer/QKgZKcB_GD1Z2AQrVM6y7XJy2gQ=/234x161/smart/arc-anglerfish-arc2-prod-elcomercio.s3.amazonaws.com/public/XVYRF5HIIZBSDLYXJJ66XC2TFA.jpg',
#     'subtitle': 'Para conocer si eres uno de los beneficiarios, solo debes ingresar tu número de DNI en la página web habilitada para este fin. El bono solo corre...',
#     'article_url': 'https://elcomercio.pe/lima/bono-380-soles-por-cuarentena-conoce-aqui-si-eres-beneficiario-del-subsidio-economico-donde-cuando-y-como-retirarlo-coronavirus-peru-link-pagina-oficial-midis-yo-me-quedo-en-casa-covid-19-estado-de-emergencia-banco-de-la-nacion-cuarentena-nndc-noticia/'}]},
#  {'diary': 'La República',
#   'articles': [{'time': '29 Mar 2020 | 3:51 h',
#     'title': 'Coronavirus en Perú: Infarto económico y recuperación',
#     'img_src': 'https://larepublica.pe/resizer/xO-UB8vkOl7vVEFFDTtszXgWm9Q=/482x290/top/smart/arc-anglerfish-arc2-prod-gruporepublica.s3.amazonaws.com/public/DWJ3LXLOVVCWTFISD6U3TVZIW4.png',
#     'subtitle': 'Para atacar la crisis económica desatada por el Covid-19 es necesario distinguir entre dos etapas. La primera estará dominada por la paralización económica interna y el congelamiento masivo de flujos de ingresos en hogares y empresas, y requerirá políticas excepcionales de alivio. La segunda estará marcada por un menor gasto agregado y la persistencia del shock externo, y demandará de medidas más tradicionales de estímulo. Ambas exigirán actuar decididamente para evitar quiebras y la ruptura de la cadena de pagos.',
#     'article_url': 'https://larepublica.pe/economia/2020/03/29/coronavirus-en-peru-infarto-economico-y-recuperacion/'},
#    {'time': '29 Mar 2020 | 2:52 h',
#     'title': 'Van 16 muertos en dos semanas de aislamiento',
#     'img_src': 'https://larepublica.pe/resizer/Bg2vsMvCg5FoxLdPWhTjqGOyHLQ=/482x290/top/smart/arc-anglerfish-arc2-prod-gruporepublica.s3.amazonaws.com/public/UEJSSZWMTFAMHC6GVE4VFCMLLQ.jpg',
#     'subtitle': 'Curva ascendente. Casos positivos de COVID-19 llegaron ayer a 671 en todo el país y en 48 horas se reportan cinco nuevas víctimas mortales. Uno de los fallecidos es un turista chino que llegó al país el 12 de marzo y luego visitó Machu Picchu.',
#     'article_url': 'https://larepublica.pe/sociedad/2020/03/29/coronavirus-peru-van-16-muertos-en-dos-semanas-de-aislamiento/'},
#    {'time': '29 Mar 2020 | 2:37 h',
#     'title': 'Coronavirus en Perú: cifra de infectados sube a 671, afirmó Martín Vizcarra [VIDEO]',
#     'img_src': 'https://larepublica.pe/resizer/5MsLOIUavbnFt77cSvSNGE-ehJo=/482x290/top/smart/arc-anglerfish-arc2-prod-gruporepublica.s3.amazonaws.com/public/GS3BSNMYBBBDRJYP35N75IF424.jpg',
#     'subtitle': 'De acuerdo al último reporte, se han procesado 10 896 muestras en todo el país a cargo del Instituto Nacional del Perú y laboratorios asociados al Ministerio de Salud. ',
#     'article_url': 'https://larepublica.pe/sociedad/2020/03/28/coronavirus-peru-aumenta-a-671-los-pacientes-con-covid-19-en-peru-afirmo-martin-vizcarra-video/'},
#    {'time': '29 Mar 2020 | 1:48 h',
#     'title': 'Detienen a regidor de Trujillo por incumplir toque de queda',
#     'img_src': 'https://larepublica.pe/resizer/5MoUEqDqJnYaMabqU-OqD72SBh0=/482x290/top/smart/arc-anglerfish-arc2-prod-gruporepublica.s3.amazonaws.com/public/HCEYFTSJRZD2VK4X2P3PEQWD3E.gif',
#     'subtitle': 'Arístides Saldaña fue intervenido en las calles de El Porvenir. Autoridad afirmó tener un permiso especial.',
#     'article_url': 'https://larepublica.pe/sociedad/2020/03/29/detienen-a-regidor-de-trujillo-por-incumplir-toque-de-queda-coronavirus-covid-19-toque-de-queda-lrnd/'},
#    {'time': '29 Mar 2020 | 1:22 h',
#     'title': 'Ministro de Salud supervisó avances en Villa Panamericana [FOTOS]',
#     'img_src': '',
#     'subtitle': 'Victor Zamora, titular del Minsa, acudió a las instalaciones de la Villa Panamericana e inspeccionó su acondicionamiento para recibir a pacientes de coronavirus.',
#     'article_url': 'https://larepublica.pe/sociedad/2020/03/29/coronavirus-en-peru-ministro-de-salud-superviso-avances-en-villa-panamericana-fotos-mdga/'}]},
#  {'diary': 'RPP',
#   'articles': [{'time': '2020-03-29T00:50:58-05:00',
#     'title': 'Cientos de ciudadanos extranjeros dejan Bolivia en vuelos solidarios por el COVID-19',
#     'img_src': 'https://e.rpp-noticias.io/normal/2020/03/29/164216_920405.jpg',
#     'subtitle': 'El Gobierno boliviano ha coordinado con embajadas y la Unión Europea para que ciudadanos regresen a sus países para estar con sus familias ante la pandemia del nuevo coronavirus. El mayor contingente de repatriados lo integran ciudadanos franceses, pero también hay españoles, belgas, holandeses, polacos e ingleses.',
#     'article_url': 'https://rpp.pe/mundo/latinoamerica/coronavirus-cientos-de-ciudadanos-extranjeros-dejan-bolivia-en-vuelos-solidarios-por-el-covid-19-noticia-1254945'},
#    {'time': '2020-03-28T22:49:14-05:00',
#     'title': 'El balón sigue rodando en Bielorrusia pese al coronavirus',
#     'img_src': 'https://e.rpp-noticias.io/normal/2020/03/28/110711_920398.jpg',
#     'subtitle': 'Pese al parón de todas las ligas europeas, el campeonato de Bielorrusia sigue. Este fin de semana se jugó la segunda fecha.\xa0',
#     'article_url': 'https://rpp.pe/futbol/futbol-mundial/coronavirus-el-balon-sigue-rodando-en-bielorrusia-pese-al-covid-19-noticia-1254941'},
#    {'time': '2020-03-28T22:45:20-05:00',
#     'title': 'Uruguay anuncia su primer fallecido por coronavirus, un exministro de 71 años',
#     'img_src': 'https://e.rpp-noticias.io/normal/2020/03/28/412741_920392.jpg',
#     'subtitle': 'Se trata del\xa0exministro de la Corte Electoral uruguaya,\xa0Rodolfo González Rissotto, informó\xa0el Sistema Nacional de Emergencias de Uruguay.',
#     'article_url': 'https://rpp.pe/mundo/actualidad/coronavirus-covid-19-uruguay-anuncia-su-primer-fallecido-un-exministro-de-71-anos-noticia-1254938'},
#    {'time': '2020-03-28T22:15:41-05:00',
#     'title': 'Justicia prohíbe al Gobierno de Bolsonaro promover campañas antiaislamiento',
#     'img_src': 'https://e.rpp-noticias.io/normal/2020/03/28/293029_920344.jpg',
#     'subtitle': 'La decisión responde a un pedido del Ministerio Público que solicitó prohibir la difusión de una campaña propagandística bautizada "Brasil\xa0no puede parar". El país vecino\xa0ya suma 97 muertes y\xa0 más de 3,400 casos confirmados.',
#     'article_url': 'https://rpp.pe/mundo/actualidad/coronavirus-brasil-justicia-prohibe-al-gobierno-de-jair-bolsonaro-promover-campanas-antiaislamiento-noticia-1254911'},
#    {'time': '2020-03-28T22:00:14-05:00',
#     'title': 'Congreso exime de responsabilidad penal a militares y policías que usen sus armas en legítima defensa durante estado de emergencia',
#     'img_src': 'https://e.rpp-noticias.io/normal/2020/03/28/520752_920383.jpg',
#     'subtitle': 'El\xa0Congreso\xa0promulgó una ley que\xa0otorga protección legal a los militares y policías\xa0que\xa0hayan causado lesión o muerte con el uso de sus armas de “manera reglamentaria”,\xa0mientras patrullan las calles para hacer cumplir la cuarentena por el\xa0coronavirus.',
#     'article_url': 'https://rpp.pe/politica/congreso/coronavirus-en-peru-congreso-exime-de-responsabilidad-penal-a-militares-y-policias-que-usen-sus-armas-en-legitima-defensa-durante-cuarentena-noticia-1254934'}]}]

# %%
gaa
# Out:
# ''
